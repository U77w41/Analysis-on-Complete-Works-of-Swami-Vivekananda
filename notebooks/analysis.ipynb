# %% [markdown]
# # Table of Contents
# * [How many volumns and chapters are there?](#chapter1)
#     * [Extracting the volumns](#section_1_1)
#     * [Extracting the chapters](#section1_2)
# * [Basic EDA](#chapter2)
#     * [Occurrence of sentences](#section2_1)
#     * [Occurrence of words](#section_2_2)
#         * [Sub Section 2.1.1](#sub_section_2_1_1)
#         * [Sub Section 2.1.2](#sub_section_2_1_2)
# * [Chapter 3](#chapter3)
#     * [Section 3.1](#section_3_1)
#         * [Sub Section 3.1.1](#sub_section_3_1_1)
#         * [Sub Section 3.1.2](#sub_section_3_1_2)
#     * [Section 3.2](#section_3_2)
#         * [Sub Section 3.2.1](#sub_section_3_2_1)

# %% [markdown]
# # How many volumns are there ?<a class="anchor" id="chapter1"></a>

# %%
# Necessary libraries
import re
from pathlib import Path 
import json
from processtext import clean, remove_sw, lemmatize, clean_text
PATH = str(Path.cwd().parent)

# Reading the dataset
with open(PATH + "/data/raw/Complete Works of Swami Vivekananda -  All Volumes - Swami Vivekananda.txt", "r") as file:
    book = file.read()

# %% [markdown]
# ## Extracting the volumns inside the book<a class="anchor" id="section_1_1"></a>

# %%
pattern = re.compile("Volume [0-9]+") # (Volumn [a-z])
volumns = re.findall(pattern, book)
volumns
# Out:
# ['Volume 1',
#  'Volume 2',
#  'Volume 3',
#  'Volume 4',
#  'Volume 5',
#  'Volume 6',
#  'Volume 7',
#  'Volume 8',
#  'Volume 9',
#  'Volume 9',
#  'Volume 9']

# %% [markdown]
# ## Extracting the chapters<a class="anchor" id="section_1_2"></a>

# %%
def search_patterns(text:str,
                    pattern)->list:
    """This function searches the whole text file for the given pattern

    Args:
        text (str): Input text
        pattern (str): Pattern in regex format

    Returns:
        list: list of search results
    """
    forward_pointer = 0
    output_results_list = []
    while (match := re.search(pattern, text[forward_pointer:])) is not None:
        forward_pointer += match.end()
        output_results_list.append(match.group().replace('\n', '').rstrip())
        # print(f"Forward Pointer: {forward_pointer} \n _____________________ text:",match.group().replace('\n', '').rstrip())
    return list(sorted(set(output_results_list)))

list_of_chapters = search_patterns(book,
                                   pattern= r'\b\d\.\d[ \.\d\w\s][ \.\d\w\s][ \.\d\w\s][ \.\d\w\s][A-Za-z0-9_]*.?(\n|.*)') # https://regexr.com/
list_of_chapters.remove('0.0032 millimeter.')
list_of_chapters
# Out:
# ['1.1 ADDRESSES AT THE PARLIAM',
#  '1.1 ADDRESSES AT THE PARLIAMENT',
#  '1.1. 1. (Sanskrit in ITRANS format)',
#  '1.1.1 RESPONSE TO WELCOME',
#  '1.1.2 WHY WE DISAGREE',
#  '1.1.3 PAPER ON HINDUISM',
#  '1.1.4 RELIGION NOT THE CRYING NEED OF INDIA',
#  '1.1.5 BUDDHISM, THE FULFILMENT OF HINDUISM',
#  '1.1.5 PAPER ON HINDUISM',
#  '1.1.6 ADDRESS AT THE FINAL SESSION',
#  '1.11.',
#  '1.2 KARMA-YOGA',
#  '1.2.1 CHAPTER 1: KARMA IN ITS EFFECT ON CHARACTER',
#  '1.2.2 CHAPTER 2: EACH IS GREAT IN HIS OWN PLACE',
#  '1.2.4 CHAPTER 4: WHAT IS DUTY?',
#  '1.2.5 CHAPTER 3: THE SECRET OF WORK',
#  '1.2.5 CHAPTER 5: WE HELP OURSELVES, NOT THE WORLD',
#  '1.2.6 CHAPTER 6: NON-ATTACHMENT IS COMPLETE SELF-',
#  '1.2.7 CHAPTER 7: FREED',
#  '1.2.7 CHAPTER 7: FREEDOM',
#  '1.2.8 CHAPTER 8: THE IDEAL OF K',
#  '1.2.8 CHAPTER 8: THE IDEAL OF KARMA-YOGA',
#  '1.2.9',
#  '1.3 RAJA-YOGA',
#  '1.3.0 PREFACE',
#  '1.3.1 CHAPTER 1: INTRODUCTORY',
#  '1.3.2 CHAPTER 2: THE FIRST STEPS',
#  '1.3.3 CHAPTER 3: PRANA',
#  '1.3.4 CHAPTER 4: THE PSYCHIC PRANA',
#  '1.3.5 CHAPTER 5: THE CONTROL OF PSYCHIC PRANA',
#  '1.3.6 CHAPTER 6: PRATYAHARA AND DHARANA',
#  '1.3.7 CHAPTER 7: DHYANA AND SAMADHI',
#  '1.3.8 CHAPTER 8: RAJA-YOGA IN BRIEF',
#  '1.3.9 PATANJALI’S YOGA APHORISMS',
#  '1.3.9.0 INTRODUCTION',
#  '1.3.9.1 PATANJALI’S YOGA APHORISMS',
#  '1.3.9.2 PATANJALI’S YOGA APHORISMS',
#  '1.3.9.3 POWERS',
#  '1.3.9.4 PATANJALI’S YOGA APHORISMS',
#  '1.3.9.5 APPENDIX',
#  '1.3.9.5 PATANJALI’S YOGA APHORISMS',
#  '1.33 p.m.',
#  '1.4 LECTURES AND DISCOURSES',
#  '1.4.1 SOUL, GOD AND RELIGION',
#  '1.4.10 STEPS TO REALISATION',
#  '1.4.11 VEDANTA AND PRIVILEGE',
#  '1.4.12 PRIVILEGE',
#  '1.4.13 KRISHNA',
#  '1.4.14 THE GITA I',
#  '1.4.15 THE GITA II',
#  '1.4.16 THE GITA III',
#  '1.4.17 MOHAMMED',
#  '1.4.18 VILVAMANGALA',
#  '1.4.19 THE SOUL AND GOD',
#  '1.4.2 THE HINDU RELIGION',
#  '1.4.20 BREATHING',
#  '1.4.21 PRACTICAL RELIGION: BREATHING AND',
#  '1.4.3 WHAT IS RELIGION?',
#  '1.4.4 VEDIC RELIGIOUS IDEALS',
#  '1.4.5 THE VEDANTA PHILOSOPHY',
#  '1.4.6 REASON AND RELIGION',
#  '1.4.7 VEDANTA AS A FACTOR IN CIVILISATION',
#  '1.4.8 THE SPIRIT AND INFLUENCE OF VEDANTA',
#  '1.4.9 STEPS OF HINDU PHILOSOPHIC THOUGHT',
#  '1.8.',
#  '2.1 WORK AND ITS SECRET',
#  '2.2 THE POWERS OF THE MIND',
#  '2.2.8.',
#  '2.238',
#  '2.29',
#  '2.3 HINTS',
#  '2.3 HINTS ON PRACTICAL SPIRITUALITY',
#  '2.4 BHAKTI OR DEVOTION',
#  '2.5 JNANA-YOGA',
#  '2.5.1 CHAPTER 1: THE NECESSITY OF RELIGION',
#  '2.5.10 CHAPTER 10: THE FREEDOM OF THE SOUL',
#  '2.5.11A CHAPTER 11A: THE COSMOS',
#  '2.5.11B CHAPTER 11B: THE COSMOS',
#  '2.5.12 CHAPTER 12: IMMORTALITY',
#  '2.5.13 CHAPTER 13: THE ATMAN',
#  '2.5.14 CHAPTER 14: THE ATMAN: ITS BONDAGE AND',
#  '2.5.15 CHAPTER 15: THE REAL AND THE APPARENT MAN',
#  '2.5.2 CHAPTER 2: THE REAL NATURE OF MAN',
#  '2.5.3 CHAPTER 3: MAYA AND ILLUSION',
#  '2.5.4 CHAPTER 4: MAYA AND THE EVOLUTION OF THE',
#  '2.5.5 CHAPTER 3: MAYA AND ILLUSION',
#  '2.5.5 CHAPTER 5: MAYA AND FREEDOM',
#  '2.5.6 CHAPTER 6: THE ABSOLUTE AND MANIFESTATION',
#  '2.5.7 CHAPTER 7: GOD IN EVERYTHING',
#  '2.5.8 CHAPTER 8: REALISATION',
#  '2.5.9 CHAPTER 9: UNITY IN DIVERSITY',
#  '2.6 PRACTICAL VEDANTA AND OTHER',
#  '2.6.1 PRACTICAL VEDANTA: PART 1',
#  '2.6.10 SOUL, NATURE, AND GOD',
#  '2.6.11 COSMOLOGY',
#  '2.6.12 A STUDY OF THE SANKHYA PHILOSOPHY',
#  '2.6.14 THE GOAL',
#  '2.6.15 SANKHYA AND VEDANTA',
#  '2.6.2 PRACTICAL VEDANTA: PART 2',
#  '2.6.4 PRACTICAL VEDANTA: PART 4',
#  '2.6.5 PRACTICAL VEDANTA: PART 3',
#  '2.6.5 THE WAY TO THE REALISATION OF A UNIVERSAL',
#  '2.6.6 THE IDEAL OF A UNIVERSAL RELIGION',
#  '2.6.7 THE OPEN SECRET',
#  '2.6.8 THE WAY TO BLESSEDNESS',
#  '2.6.9 YAJNAVALKYA AND MAITREY-',
#  '2.6.9 YAJNAVALKYA AND MAITREYI',
#  '2.60',
#  '2.63',
#  '2.67',
#  '2.7 REPORTS',
#  '2.7 REPORTS IN AMERICAN',
#  '2.7.1 NOTE',
#  '2.7.10 LESS DOCTRINE AND MORE',
#  '2.7.10 LESS DOCTRINE AND MORE BREAD',
#  '2.7.11 THE RELIGION OF BUDDHA',
#  '2.7.12 ALL RELIGIONS ARE GOOD',
#  '2.7.13 THE HINDU VIEW OF LIFE',
#  '2.7.14 IDEALS OF WOMANHOOD',
#  '2.7.15 TRUE BUDDHISM',
#  '2.7.16 INDIA’S GIFT TO THE WORLD',
#  '2.7.17 CHILD WIDOWS OF INDIA',
#  '2.7.18 SOME CUSTOMS OF THE HINDUS',
#  '2.7.2 DIVINITY OF MAN',
#  '2.7.3 SWAMI VIVEKANANDA ON INDIA',
#  '2.7.4 RELIGIOUS HARMONY',
#  '2.7.5 FROM FAR OFF INDIA',
#  '2.7.5 SWAMI VIVEKANANDA ON INDIA',
#  '2.7.6 AN EVENING WITH OUR HINDU COUSINS',
#  '2.7.7 THE MANNERS AND CUSTOMS OF INDIA',
#  '2.7.8 THE RELIGIONS OF INDIA',
#  '2.7.9 SECTS AND DOCTRINES IN INDIA',
#  '3.1 LECTURES AND DISCOURSES',
#  '3.1.1 UNITY, THE GOAL OF RELIGION',
#  '3.1.2 THE FREE SOUL',
#  '3.1.3 ONE EXISTENCE APPEARING AS MANY',
#  '3.2 BHAKTI-YOGA',
#  '3.2 CHAPTER 2: THE BHAKTA’S RENUNCIATION',
#  '3.2.1 CHAPTER 1: DEFINITION OF BHAKTI',
#  '3.2.10 CHAPTER 10: THE METHOD AND THE MEANS',
#  '3.2.2 CHAPTER 2: THE PHILOSOPHY OF ISHVARA',
#  '3.2.4 CHAPTER 4: THE NEED OF GURU',
#  '3.2.5 CHAPTER 3: SPIRITUAL REALISATION, THE AIM OF',
#  '3.2.5 CHAPTER 5: QUALIFICATIONS OF THE ASPIRANT',
#  '3.2.6 CHAPTER 6: INCARNATE TEACHERS AND',
#  '3.2.7 CHAPTER 7: THE MANTRA: OM:',
#  '3.2.7 CHAPTER 7: THE MANTRA: OM: WORD AND WISDOM',
#  '3.2.8 CHAPTER 8: WORSHIP OF SUBSTITUTES AND',
#  '3.2.9 CHAPTER 9: THE CHOSEN IDEAL',
#  '3.3 PARA-BHAKTI OR SUPREME',
#  '3.3.1 CHAPTER 1: THE PREPARATORY RENUNCIATION',
#  '3.3.10 CHAPTER 10: CONCLUSION',
#  '3.3.2 CHAPTER 2: THE BHAKTA’S RENUNCIATION RESULTS',
#  '3.3.3 CHAPTER 3: THE NATURALNESS OF BHAKTI-YOGA',
#  '3.3.4 CHAPTER 4: THE FORMS OF LOVE —',
#  '3.3.5 CHAPTER 5: UNIVERSAL LOVE AND HOW',
#  '3.3.7 CHAPTER 7: THE TRIANGLE OF LOVE',
#  '3.3.8 CHAPTER 8: THE GOD OF LOVE IS HIS OWN PROOF',
#  '3.4 LEGTURES FROM COLOMBO TO',
#  '3.4.1 FIRST PUBLIC LECTURE IN THE EAST',
#  '3.4.10 REPLY TO THE ADDRESS OF WELCOME AT MADRAS',
#  '3.4.11 MY PLAN OF CAMPAIGN',
#  '3.4.12 VEDANTA IN ITS APPLICATION TO INDIAN LIFE',
#  '3.4.13 THE SAGES OF INDIA',
#  '3.4.14 THE WORK BEFORE US',
#  '3.4.15 THE FUTURE OF INDIA',
#  '3.4.15 THE SAGES OF INDIA',
#  '3.4.16 ON CHARITY',
#  '3.4.17 ADDRESS OF WELCOME PRESENTED AT CALCUTTA',
#  '3.4.18 THE VEDANTA IN ALL ITS PHASES',
#  '3.4.19 ADDRESS OF WELCOME AT ALMORA AND REPLY',
#  '3.4.2 VEDANTISM',
#  '3.4.20 VEDIC TEACHING IN THEORY AND PRACTICE',
#  '3.4.21 BHAKTI',
#  '3.4.22 THE COMMON BASES OF HINDUISM',
#  '3.4.23 BHAKTI',
#  '3.4.24 THE VEDANTA',
#  '3.4.25 VEDANTISM',
#  '3.4.26 THE INFLUENCE OF INDIAN SPIRITUAL THO!',
#  '3.4.26 THE INFLUENCE OF INDIAN SPIRITUAL THOUGHT',
#  '3.4.27 SANNYASA: ITS IDEAL AND PRACTICE',
#  '3.4.28 WHAT HAVE I LEARNT?',
#  '3.4.29 THE RELIGION WE ARE BORN IN',
#  '3.4.3 REPLY TO THE ADDRESS OF WELCOME AT PAMBAN',
#  '3.4.4 ADDRESS AT THE RAMESWARAM TEMPLE ON REAL',
#  '3.4.5 REPLY TO THE ADDRESS OF WELCOME AT RAMNAD',
#  '3.4.6 REPLY TO THE ADDRESS OF WELCOME AT',
#  '3.4.7 REPLY TO THE ADDRESS OF WELCOME AT',
#  '3.4.8 REPLY TO THE ADDRESS OF WELCOME AT MADURA',
#  '3.4.9 THE MISSION OF THE VEDANTA',
#  '3.5 REPORTS IN AMERICAN',
#  '3.5.1 INDIA: HER RELIGION AND CUSTOMS',
#  '3.5.10 PLEA FOR TOLERANCE',
#  '3.5.11 MANNERS AND CUSTOMS IN INDI',
#  '3.5.11 MANNERS AND CUSTOMS IN INDIA',
#  '3.5.12 HINDOO PHILOSOPHY',
#  '3.5.13 MIRACLES',
#  '3.5.14 THE DIVINITY OF MAN',
#  '3.5.15 THE LOVE OF GOD',
#  '3.5.16 THE WOMEN OF INDIA',
#  '3.5.2 HINDUS AT THE FAIR',
#  '3.5.3 AT THE PARLIAMENT OF RELIGIONS',
#  '3.5.3 CHAPTER 3: THE NATURALNESS OF BHAKTI-YOGA',
#  '3.5.4 CHAPTER 4: THE FORMS OF LOVE —',
#  '3.5.4 PERSONAL TRAITS',
#  '3.5.5 CHAPTER 5: UNIVERSAL LOVE AND HOW IT LEADS',
#  '3.5.5 REINCARNATION',
#  '3.5.6 HINDU CIVILISATION',
#  '3.5.7 AN INTERESTING LECTURE',
#  '3.5.8 CHAPTER 8: THE GOD OF LOVE IS HIS OWN PROOF',
#  '3.5.8 THE HINDOO RELIGION',
#  '3.5.9 THE HINDOO MONK',
#  '3.53.6 CHAPTER 6: THE HIGHER KNOWLEDGE AND THE',
#  '3.53.9 CHAPTER 9: HUMAN REPRESENTATIONS OF THE',
#  '3.6 BUDDHISTIC INDIA',
#  '3.6.36 MISS MARY HALE',
#  '4.1 ADDRESSES ON BHAKTI-YOGA',
#  '4.1.1 THE PREPARATION',
#  '4.1.2 THE FIRST STEPS',
#  '4.1.4 THE NEED OF SYMBOLS',
#  '4.1.5 THE CHIEF SYMBOLS',
#  '4.1.5 THE TEACHER OF SPIRITUALITY',
#  '4.1.6 THE ISHTA',
#  '4.2 LECTURES AND DISCOURSES',
#  '4.2.1 THE RAMAYANA',
#  '4.2.10 INDIAN RELIGIOUS THOUGHT',
#  '4.2.11 THE BASIS FOR PSYCHIC OR SPIRITUAL RESEARCH',
#  '4.2.12 ON ART IN INDIA',
#  '4.2.13 IS INDIA A BENIGHTED COUNTRY?',
#  '4.2.14 THE CLAIMS OF RELIGION',
#  '4.2.15 CONCENTRATION',
#  '4.2.16 MEDITATION',
#  '4.2.17 THE PRACTICE OF RELIGION',
#  '4.2.2 THE MAHABHARATA',
#  '4.2.3 THOUGHTS ON THE GITA',
#  '4.2.4 THE STORY OF JADA BHARATA',
#  '4.2.5 THE STORY OF PRAHLADA',
#  '4.2.6 THE GREAT TEACHERS OF THE WORLD',
#  '4.2.7 ON LORD BUDDHA',
#  '4.2.8 CHRIST, THE MESSENGER',
#  '4.2.9 MY MASTER',
#  '4.3 WRITINGS: PROSE',
#  '4.3.1 IS THE SOUL IMMORTAL?',
#  '4.3.10 REPLY TO THE ADDRESS OF THE MAHARAJA OF',
#  '4.3.11 REPLY TO THE MADRAS ADDRESS',
#  '4.3.12 A MESSAGE OF SYMPATHY TO A FRIEND',
#  '4.3.13 WHAT WE BELIEVE IN',
#  '4.3.14 OUR DUTY TO THE MASSES',
#  '4.3.15 REPLY TO THE CALCUTTA ADDRESS',
#  '4.3.15 WHAT WE BELIEVE IN',
#  '4.3.16 TO MY BRAVE BOYS',
#  '4.3.17 A PLAN OF WORK FOR INDIA',
#  '4.3.18 FUNDAMENTALS OF RELIGION',
#  '4.3.2 REINCARNATION',
#  '4.3.3 ON DR. PAUL DEUSSEN',
#  '4.3.4 ON PROFESSOR MAX MULLER',
#  '4.3.5 SKETCH OF THE LIFE OF PAVHARI BABA',
#  '4.3.6 ARYANS AND TAMILIANS',
#  '4.3.7 THE SOCIAL CONFERENCE ADDRESS',
#  '4.3.8 INDIA’S MESSAGE TO THE WORLD',
#  '4.3.9 STRAY REMARKS ON THEOSOPHY',
#  '4.4.1 KALI THE MOTHER',
#  '4.4.12 (adapted).',
#  '4.4.2 ANGELS UNAWARES',
#  '4.4.3 TO THE AWAKENED INDIA',
#  '4.4.4 REQUIESCAT IN PACE',
#  '4.4.5 HOLD ON YET A WHILE, BRAVE HEART',
#  '4.4.6 NIRVANASHATKAM, OR SIX STANZAS ON NIRVANA',
#  '4.4.7 THE SONG OF THE SANNYASIN',
#  '4.4.8 PEACE',
#  '4.4.WRITINGS: POEMS',
#  '4.5 TRANSLATION: PROSE',
#  '4.5. [351] The “Grand Old Lady” was a figure in a children’s game, whose touch put one',
#  '4.5.1 THE PROBLEM OF MODERN INDIA AND ITS',
#  '4.5.16 TO MY BRAVE BOYS',
#  '4.5.2 RAMAKRISHNA: HIS LIFE AND SAYINGS',
#  '4.5.3 THE PARIS CONGRESS OF THE HISTORY OF',
#  '4.5.4 KNOWLEDGE: ITS SOURCE AND ACQUIREMENT',
#  '4.5.5 MODERN INDIA',
#  '4.5.6 THE EDUCATION THAT INDIA NEEDS',
#  '4.5.7 OUR PRESENT SOCIAL PROBLEMS',
#  '4.6 TRANSLATION: POEMS',
#  '4.6.1 TO A FRIEND',
#  '4.6.2 THE HYMN OF CREATION',
#  '4.6.3 THE HYMN OF SAMADHI',
#  '4.6.4 A HYMN TO THE DIVINE MOTHER',
#  '4.6.5 A HYMN TO SHIVA',
#  '4.6.5 AHYMN TO SHIVA',
#  '4.6.6 A HYMN TO THE DIVINITY OF SHRI RAMAKRISHNA',
#  '4.6.6 AHYMN TO THE DIVINITY OF SHRI RAMAKRISHNA',
#  '4.6.8 A SONG I SING TO THEE',
#  '5.00 a month in my country. Would',
#  '5.1 EPISTLES FIRST SERIES',
#  '5.1.0 NOTE',
#  '5.1.1 FAKIR',
#  '5.1.10 ALASINGA',
#  '5.1.100 JOE',
#  '5.1.101 MOTHER',
#  '5.1.102 SWARUP',
#  '5.1.104 SHASHI',
#  '5.1.105 JOE',
#  '5.1.105 MARY',
#  '5.1.106 JOE',
#  '5.1.107 JOE',
#  '5.1.108 MARY',
#  '5.1.109 CHRISTINE',
#  '5.1.11 ALASINGA',
#  '5.1.110 MARY',
#  '5.1.111 BLESSED AND BELOVED',
#  '5.1.112 BLESSED AND BELOVED',
#  '5.1.113 JOE',
#  '5.1.114 SWARUP',
#  '5.1.115 MOTHER',
#  '5.1.116 SISTER NIVEDITA',
#  '5.1.117 RAKHAL',
#  '5.1.118 RAKHAL',
#  '5.1.119 RAKHAL',
#  '5.1.12 SISTER',
#  '5.1.120 RAKHAL',
#  '5.1.121 JOE',
#  '5.1.122 JOE',
#  '5.1.123 DHIRA MATA',
#  '5.1.13 ALASINGA',
#  '5.1.14 ALASINGA',
#  '5.1.15 KIDI',
#  '5.1.16 SISTER',
#  '5.1.17 ALASINGA',
#  '5.1.18 ALASINGA',
#  '5.1.19 VEHEMIA',
#  '5.1.2 PANDITJI MAHARAJ',
#  '5.1.20 SISTER',
#  '5.1.21 ALASINGA',
#  '5.1.22 ALASINGA',
#  '5.1.23 KIDI',
#  '5.1.24 ALASINGA',
#  '5.1.25 ALASINGA',
#  '5.1.26 DHARMAPALA',
#  '5.1.27 ALASINGA',
#  '5.1.28 MRS. BULL',
#  '5.1.29 G. G.',
#  '5.1.30 ALASINGA',
#  '5.1.31 MRS. OLE BULL',
#  '5.1.34 SISTER',
#  '5.1.36 SISTER',
#  '5.1.38 S—',
#  '5.1.39 ALASINGA',
#  '5.1.4 ALASINGA',
#  '5.1.40 ALASINGA',
#  '5.1.41 FRIEND',
#  '5.1.42 KIDI',
#  '5.1.43 ALASINGA',
#  '5.1.44 MRS. WILLIAM STURGES',
#  '5.1.45 MOTHER',
#  '5.1.46 FRIEND',
#  '5.1.47 MAHARAJA OF KHETRI',
#  '5.1.48 FRIEND',
#  '5.1.49 ALASINGA',
#  '5.1.5 ALASINGA',
#  '5.1.50 MRS. BULL',
#  '5.1.51 MRS. OLE BULL',
#  '5.1.51 STURDY',
#  '5.1.52 ALASINGA',
#  '5.1.52 SISTER',
#  '5.1.53 ALASINGA',
#  '5.1.54 ALASINGA',
#  '5.1.55 ALASINGA',
#  '5.1.56 SISTER',
#  '5.1.57 ALASINGA',
#  '5.1.57 BLESSED AND BELOVED',
#  '5.1.58 ALASINGA',
#  '5.1.59 ALASINGA',
#  '5.1.6 HARIPADA',
#  '5.1.60 ALASINGA',
#  '5.1.61 NANJUNDA RAO',
#  '5.1.62 NANJUNDA RAO',
#  '5.1.63 ALASINGA',
#  '5.1.64 ALASINGA',
#  '5.1.65 BLESSED AND BELOVED',
#  '5.1.66 NANJUNDA RAO',
#  '5.1.67 ALASINGA',
#  '5.1.68 ALASINGA',
#  '5.1.69 ALASINGA',
#  '5.1.7 FRIENDS',
#  '5.1.70 INDIAN MIRROR',
#  '5.1.71 ALASINGA',
#  '5.1.72 ALASINGA',
#  '5.1.73 MADAM',
#  '5.1.74 HONOURED MADAM',
#  '5.1.75 DOCTOR SHASHI',
#  '5.1.76 MR._',
#  '5.1.76 MR.__',
#  '5.1.77 SARAT CHANDRA',
#  '5.1.78 SISTER',
#  '5.1.79 MOTHER',
#  '5.1.8 ALASINGA',
#  '5.1.80 JOE',
#  '5.1.81 JAGMOHANLAL',
#  '5.1.82 M.',
#  '5.1.83 YOUR HIGHNESS',
#  '5.1.84 YOUR HIGHNESS',
#  '5.1.85 YOUR HIGHNESS',
#  '5.1.86 YOUR HIGHNESS',
#  '5.1.87 YOUR HIGHNESS',
#  '5.1.88 YOUR HIGHNESS',
#  '5.1.89 MOTHER',
#  '5.1.9 SHARAT',
#  '5.1.90 JOE',
#  '5.1.91 FRIEND',
#  '5.1.92 __',
#  '5.1.93 SHASHI',
#  '5.1.94 MOTHER',
#  '5.1.95 STURDY',
#  '5.1.96 MOTHER',
#  '5.1.97 SHASHI',
#  '5.1.98 MOTHER',
#  '5.1.99 JOE',
#  '5.2 INTERVIEWS',
#  '5.2.1 MIRACLES',
#  '5.2.10 ON INDIAN WOMEN — THEIR PAST, PRESENT AND',
#  '5.2.11 ON THE BOUNDS OF HINDUISM',
#  '5.2.2 AN INDIAN YOGI IN LONDON',
#  '5.2.22 ALASINGA',
#  '5.2.3 INDIA’S MISSION',
#  '5.2.4 INDIA AND ENGLAND',
#  '5.2.5 INDIAN MISSIONARY’S MISSION TO ENGLAND',
#  '5.2.6 WITH THE SWAMI VIVEKANANDA AT MADURA',
#  '5.2.7 THE ABROAD AND THE PROBLEMS AT HOME',
#  '5.2.8 THE MISSIONARY WORK OF THE FIRST HINDU',
#  '5.2.9 REAWAKENING OF HINDUISM ON A',
#  '5.2.9 REAWAKENING OF HINDUISM ON A NATIONAL',
#  '5.3 NOTES FROM LECTURES AND',
#  '5.3.1 ON KARMA-YOGA',
#  '5.3.10 THE SANNYASIN',
#  '5.3.11 THE SANNYASIN AND THE HOUSEHOLDER',
#  '5.3.12 THE EVILS OF ADHIKARIVADA',
#  '5.3.13 ON BHAKTI-YOGA',
#  '5.3.14 ISHVARA AND BRAHMAN',
#  '5.3.15 ON JNANA-YOGA',
#  '5.3.16 THE CAUSE OF ILLUSION',
#  '5.3.17 EVOLUTION',
#  '5.3.18 BUDDHISM AND VEDANTA',
#  '5.3.19 ON THE VEDANTA PHILOSOPHY',
#  '5.3.20 LAW AND FREEDOM',
#  '5.3.21 THE GOAL AND METHODS OF REALISATION',
#  '5.3.22 WORLD-WIDE UNITY',
#  '5.3.23 THE AIM OF RAJA-YOGA',
#  '5.3.3 WORK IS WORSHIP',
#  '5.3.4 WORK WITHOUT MOTIVE',
#  '5.3.5 SADHANAS OR PREPARATIONS FOR HIGHER LIFE',
#  '5.3.6 THE COSMOS AND THE SELF',
#  '5.3.7 WHO IS A REAL GURU?',
#  '5.3.7 WHOIS A REAL GURU?',
#  '5.3.8 ON ART',
#  '5.3.9 ON LANGUAGE',
#  '5.4 QUESTIONS AND ANSWERS',
#  '5.4.1 DISCUSSIONS AT THE GRADUATE PHILOSOPHICAL',
#  '5.4.2 AT THE 20TH CENTURY CLUB OF BOSTON, USA',
#  '5.4.3 AT THE BROOKLYN ETHICAL SOCIETY, BROOKLYN,',
#  '5.4.4 SELECTIONS FROM THE MATH DIARY',
#  '5.4.5 YOGA, VAIRAGYA, TAPASYA, LOVE',
#  '5.4.6 INANSWER TO NIVEDITA',
#  '5.4.7 GURU, AVATARA, YOGA, JAPA, SEVA',
#  '5.5.1',
#  '5.5.1 SHRI SURENDRA NATH DAS GUPTA',
#  '5.5.13 ON BHAKTI-YOGA',
#  '5.5.19 ON THE VEDANTA PHILOSOPHY',
#  '5.5.2',
#  '5.5.2 ON FANATICISM',
#  '5.5.21 THE GOAL AND METHODS OF REALISATION',
#  '5.5.23 THE AIM OF RAJA-YOGA',
#  '5.5.4',
#  '5.5.5 SADHANAS OR PREPARATIONS FOR HIGHER LIFE',
#  '5.53.20 LAW AND FREEDOM',
#  '5.53.22 WORLD-WIDE UNITY',
#  '5.7.1 REASON, FAITH AND LOVE',
#  '5.7.2 SIX SANSKRIT MOTTOES',
#  '5.7.3 THE MESSAGE OF DIVINE WISDOM',
#  '5.7.4 THE BELUR MATH: AN APPEAL',
#  '5.7.5 THE ADVAITA ASHRAMA, HIMALAYAS',
#  '5.7.6 THE RAMAKRISHNA HOME OF SERVICE VARANASI:',
#  '5.7.7 WHO KNOWS HOW MOTHER PLAYS!',
#  '5.7.8 TO THE FOURTH OF J —',
#  '5.7.8 TO THE FOURTH OF JULY',
#  '5.7.9 THE EAST AND THE WEST',
#  '5.9 CHAPTER 9: UNITY IN DIVERSITY',
#  '6.1 LECTURES AND DISCOURSES',
#  '6.1.1 THE METHODS AND PURPOSE OF RELIGION',
#  '6.1.10 DIVINE LOVE',
#  '6.1.2 THE NATURE OF THE SOUL AND ITS GOAL',
#  '6.1.3 THE IMPORTANCE OF PSYCHOLOGY',
#  '6.1.4 NATURE AND MAN',
#  '6.1.5 CONCENTRATION AND BREATHING',
#  '6.1.5 THE IMPORTANCE OF PSYCHOLOGY',
#  '6.1.6 INTRODUCTION TO JNANA-YOGA',
#  '6.1.7 THE VEDANTA PHILOSOPHY AND CHRISTIANITY',
#  '6.1.8 WORSHIPPER AND WORSHIPPED',
#  '6.1.9 FORMAL WORSHIP',
#  '6.2 NOTES OF CLASS TALKS AND',
#  '6.2.1 RELIGION AND SCIENCE',
#  '6.2.10 ON BHAKTI-YOGA',
#  '6.2.11 ON JNANA-YOGA',
#  '6.2.12 THE REALITY AND SHADOW',
#  '6.2.13 HOW TO BECOME FREE',
#  '6.2.14 SOUL AND GOD',
#  '6.2.15 THE GOAL',
#  '6.2.16 ON PROOF OF RELIGION',
#  '6.2.17 THE DESIGN THEORY',
#  '6.2.18 SPIRIT AND NATURE',
#  '6.2.19 THE PRACTICE OF RELIGION',
#  '6.2.2 RELIGION IS REALISATION',
#  '6.2.20 FRAGMENTARY NOTES ON THE RAMAYANA',
#  '6.2.21 NOTES TAKEN DOWN IN MADRAS, 1892-93',
#  '6.2.22 CONCENTRATION',
#  '6.2.23 THE POWER OF THE MIND',
#  '6.2.24 LESSONS ON RAJA-YOGA',
#  '6.2.25 LESSONS ON BHAKTI-YOGA',
#  '6.2.26 MOTHER-WORSHIP',
#  '6.2.27 NARADA-BHAKTI-SUTRAS',
#  '6.2.3 RELIGION IS SELF-ABNEGATION',
#  '6.2.4 UNSELFISH WORK IS TRUE RENUNCIATION',
#  '6.2.5 FREEDOM OF THE SELF',
#  '6.2.6 NOTES ON VEDANTA',
#  '6.2.7 HINDU AND GREEK',
#  '6.2.8 THOUGHTS ON THE VEDAS AND THE UPANISHADS',
#  '6.2.9 ON RAJA-YOGA',
#  '6.27.',
#  '6.3 WRITINGS: PROSE AND POEMS',
#  '6.3.1 HISTORICAL EVOLUTION OF INDIA',
#  '6.3.10 MATTER FOR SERIOUS THOUGHT',
#  '6.3.11 SHIVA’S DEMON',
#  '6.3.2 THE STORY OF THE BOY GOPALA',
#  '6.3.4 THE CUP',
#  '6.3.5 A BENEDICTION',
#  '6.3.5 MY PLAY IS DONE',
#  '6.3.6 THE HYMN OF GREATION',
#  '6.3.7 ON THE SEA’S BOSOM',
#  '6.3.8 HINDUISM AND SHRI RAMAKRISHNA',
#  '6.3.9 THE BENGALI LANGUAGE',
#  '6.38 MISS ISABELLE MCKINDLEY',
#  '6.4 EPISTLES —- SECOND SERIES',
#  '6.4.1 PRAMADADAS MITRA',
#  '6.4.1 PRAMADADAS MITRA (54)',
#  '6.4.10 PRAMADADAS MITRA',
#  '6.4.100 SHASHI',
#  '6.4.101 SHASHI',
#  '6.4.102 FRANKINCENSE',
#  '6.4.103 MRS. BULL',
#  '6.4.104 MRS. BULL',
#  '6.4.105 LALA BADRI SHAH',
#  '6.4.106 SHASHI',
#  '6.4.107 MRS. BULL',
#  '6.4.108 SISTER',
#  '6.4.109 JOE JOE',
#  '6.4.11 PRAMADADAS MITRA',
#  '6.4.110 MISS S. E. WALDO',
#  '6.4.111 MRS. BULL',
#  '6.4.112 MISS MARY HALE',
#  '6.4.113 MRS. BULL',
#  '6.4.114 LALA BADRI SHAH',
#  '6.4.115 DEAR __',
#  '6.4.116 SISTERS',
#  '6.4.117 ALBERTA',
#  '6.4.118 MRS. BULL',
#  '6.4.119 FRANKINCENSE',
#  '6.4.12 PRAMADADAS MITRA',
#  '6.4.120 ALBERTA',
#  '6.4.121 MARY',
#  '6.4.122 MRS. BULL',
#  '6.4.123 MARY',
#  '6.4.124 PRAMADADAS MITRA',
#  '6.4.125 MARY',
#  '6.4.125 SHUDDHANANDA',
#  '6.4.126 MISS NOBLE',
#  '6.4.127 RAKHAL',
#  '6.4.128 AKHANDANANDA',
#  '6.4.129 RAKHAL',
#  '6.4.13 PRAMADADAS MITRA',
#  '6.4.130 RAKHAL',
#  '6.4.131 AKHANDANANDA',
#  '6.4.131 AKHANDANAND£',
#  '6.4.132 AKHANDANANDA',
#  '6.4.133 MRS. BULL',
#  '6.4.134 MOTHER',
#  '6.4.135 SARADA',
#  '6.4.136 AKHANDANANDA',
#  '6.4.137 RAKHAL',
#  '6.4.138 M_',
#  '6.4.138 M__',
#  '6.4.139 MOTHER',
#  '6.4.14 PRAMADADAS MITRA',
#  '6.4.140 MOTHER',
#  '6.4.141 MARGOT',
#  '6.4.142 SARFARAZ HUSAIN',
#  '6.4.143 MARGOT',
#  '6.4.144 DEAR__',
#  '6.4.145 MRS. BULL',
#  '6.4.146 DEAR_',
#  '6.4.146 DEAR__',
#  '6.4.147 MRS. BULL',
#  '6.4.148 MARGOT',
#  '6.4.149 MARGOT',
#  '6.4.15 BALARAM BOSE',
#  '6.4.150 MRS. BULL',
#  '6.4.151 MARGOT',
#  '6.4.152 MARGOT',
#  '6.4.153 MRS. BULL',
#  '6.4.153 NIVEDITA',
#  '6.4.154 AKHANDANANDA',
#  '6.4.154 MOTHER',
#  '6.4.155 NIVEDITA',
#  '6.4.156 AKHANDANANDA',
#  '6.4.156 NIVEDITA',
#  '6.4.157 MARGOT',
#  '6.4.157 RAKHAL',
#  '6.4.158 JOE',
#  '6.4.159 NIVEDITA',
#  '6.4.16 PRAMADADAS MITRA',
#  '6.4.160 NIVEDITA',
#  '6.4.161 NIVEDITA',
#  '6.4.162 NIVEDITA',
#  '6.4.163 MOTHER',
#  '6.4.164 ALBERTA',
#  '6.4.165 JOE',
#  '6.4.166 NIVEDITA',
#  '6.4.167 JOE',
#  '6.4.168 NIVEDITA',
#  '6.4.17 PRAMADADAS MITRA',
#  '6.4.18 PRAMADADAS MITRA',
#  '6.4.19 PRAMADADAS MITRA',
#  '6.4.2 PRAMADADAS MITRA',
#  '6.4.20 PRAMADADAS MITRA',
#  '6.4.21 PRAMADADAS MITRA',
#  '6.4.22 PRAMADADAS MITRA',
#  '6.4.23 AKHANDANANDA',
#  '6.4.24 PRAMADADAS MITRA',
#  '6.4.25 PRAMADADAS MITRA',
#  '6.4.26 PRAMADADAS MITRA',
#  '6.4.27 AKHANDANANDA',
#  '6.4.28 AKHANDANANDA',
#  '6.4.29 PRAMADADAS MITRA',
#  '6.4.3 PRAMADADAS MITRA',
#  '6.4.30 ABHEDANANDA',
#  '6.4.31 PRAMADADAS MITRA',
#  '6.4.32 PRAMADADAS MITRA',
#  '6.4.33 PRAMADADAS MITRA',
#  '6.4.34 SARADANANDA',
#  '6.4.35 GOVINDA SAHAY',
#  '6.4.35 PRAMADADAS MITRA',
#  '6.4.36 GOVINDA SAHAY',
#  '6.4.37 GOVINDA SAHAY',
#  '6.4.38 NANJUNDA RAO',
#  '6.4.39 MOTHER',
#  '6.4.4 PRAMADADAS MITRA',
#  '6.4.40 MAHARAJA OF KHETRI',
#  '6.4.41 RAMAKRISHNANANDA',
#  '6.4.42 RAO BAHADUR NARASIMHACHARIAR',
#  '6.4.43 SISTERS',
#  '6.4.44 SISTERS',
#  '6.4.45 BROTHERS',
#  '6.4.46 MOTHER SARA',
#  '6.4.47 BROTHER DISCIPLES',
#  '6.4.48 MRS. BULL',
#  '6.4.49 RAMAKRISHNANANDA',
#  '6.4.5 M-',
#  '6.4.5 M—',
#  '6.4.5 PRAMADADAS MITRA',
#  '6.4.50 MRS. BULL',
#  '6.4.51 NANJUNDA RAO',
#  '6.4.52 GOVINDA SAHAY',
#  '6.4.53 GOVINDA SAHAY',
#  '6.4.54 RAMAKRISHNANANDA [67]',
#  '6.4.55 AKHANDANANDA',
#  '6.4.56 BROTHER DISCIPLES',
#  '6.4.57 MRS. BULL',
#  '6.4.58 SARADA',
#  '6.4.59 SANYAL',
#  '6.4.6 PRAMADADAS MITRA',
#  '6.4.60 MRS. BULL',
#  '6.4.61 MRS. BULL',
#  '6.4.62 MRS. BULL',
#  '6.4.63 SHASHI',
#  '6.4.64 MRS. BULL',
#  '6.4.65 MRS. BULL',
#  '6.4.66 MRS. BULL',
#  '6.4.67 MRS. BULL',
#  '6.4.68 MRS. BULL',
#  '6.4.69 SHASHI',
#  '6.4.7 PRAMADADAS MITRA',
#  '6.4.70 ALBERTA',
#  '6.4.71 RAKHAL',
#  '6.4.72 AKHANDANANDA',
#  '6.4.74 RAKHAL',
#  '6.4.75 BROTHER DISCIPLES',
#  '6.4.75 SHASHI',
#  '6.4.76 RAKHAL',
#  '6.4.77 SHASHI',
#  '6.4.78 RAKHAL',
#  '6.4.79 MRS. BULL',
#  '6.4.8 PRAMADADAS MITRA',
#  '6.4.80 MRS. BULL',
#  '6.4.81 MOTHER',
#  '6.4.82 DEAR—',
#  '6.4.84 MRS. BULL',
#  '6.4.85 AKHANDANANDA',
#  '6.4.85 RAKHAL',
#  '6.4.86 MRS. BULL',
#  '6.4.87 ALBERTA',
#  '6.4.88 MRS. BULL',
#  '6.4.89 MRS. BULL',
#  '6.4.9 PRAMADADAS MITRA',
#  '6.4.90 SISTER',
#  '6.4.91 SARADA',
#  '6.4.92 YOGEN',
#  '6.4.94 SARADA',
#  '6.4.95 MRS. BULL',
#  '6.4.96 MRS. BULL',
#  '6.4.97 SARADA',
#  '6.4.98 MRS. BULL',
#  '6.4.99 MRS. BULL',
#  '6.5 C 2 VE RSATIONS AND DIALOGUES',
#  '6.5 GONVERSATIONS AND DIALOGUES',
#  '6.5.1 SHARATCHANDRA CHAKRAVARTY',
#  '6.5.10 SHARATCHANDRA CHAKRAVARTY',
#  '6.5.108 SISTER',
#  '6.5.11 SHARATCHANDRA CHAKRAVARTY',
#  '6.5.12 SHARATCHANDRA CHAKRAVARTY',
#  '6.5.158 JOE',
#  '6.5.2 SHARATCHANDRA CHAKRAVARTY',
#  '6.5.4 SHARATCHANDRA CHAKRAVARTY',
#  '6.5.5 SHARATCHANDRA CHAKRAVARTY',
#  '6.5.6 SHARATCHANDRA CHAKRAVARTY',
#  '6.5.7 SHARATCHANDRA CHAKRAVARTY',
#  '6.5.8 SHARATCHANDRA CHAKRAVARTY',
#  '6.5.9 SHARATCHANDRA CHAKRAVARTY',
#  '6.53.10 MATTER FOR SERIOUS THOUGHT',
#  '7.1 INSPIRED TALKS',
#  '7.1.1 WEDNESDAY, JUNE 18, 1895',
#  '7.1.10 MONDAY, JULY 1, 1895',
#  '7.1.11 TUESDAY, JULY 2, 1895',
#  '7.1.12 WEDNESDAY, JULY 3, 1895',
#  '7.1.13 FRIDAY, JULY 5, 1895',
#  '7.1.14 SATURDAY, JULY 6, 1895',
#  '7.1.15 SUNDAY, JULY 7, 1895',
#  '7.1.16 MONDAY, JULY 8, 1895',
#  '7.1.17 TUESDAY, JULY 9, 1895',
#  '7.1.18 WEDNESDAY, JULY 10, 1895',
#  '7.1.19 THURSDAY, JULY 11, 1895',
#  '7.1.2 SUNDAY, JUNE 23, 1895',
#  '7.1.20 FRIDAY, JULY 12, 1895',
#  '7.1.21 SATURDAY, JULY 13, 1895',
#  '7.1.22 SUNDAY, JULY 14, 1895',
#  '7.1.23 MONDAY, JULY 15, 1895',
#  '7.1.24 TUESDAY, JULY 16, 1895',
#  '7.1.25 WEDNESDAY, JULY 17, 1895',
#  '7.1.26 THURSDAY, JULY 18, 1895',
#  '7.1.28 SATURDAY, JULY 20, 1895',
#  '7.1.29 SUNDAY, JULY 21, 1895',
#  '7.1.3 MONDAY, JUNE 24, 1895',
#  '7.1.30 TUESDAY, JULY 23, 1895',
#  '7.1.31 WEDNESDAY, JULY 24, 1895',
#  '7.1.32 THURSDAY, JULY 25, 1895',
#  '7.1.33 FRIDAY, JULY 26, 1895',
#  '7.1.34 SATURDAY, JULY 27, 1895',
#  '7.1.35 SUNDAY, JULY 28, 1895',
#  '7.1.36 MONDAY, JULY 29, 1895',
#  '7.1.37 TUESDAY, JULY 30, 1895',
#  '7.1.38 WEDNESDAY, JULY 31, 1895',
#  '7.1.39 THURSDAY, AUGUST 1, 1895',
#  '7.1.4 TUESDAY, JUNE 25, 1895',
#  '7.1.40 AUGUST 2, 1895',
#  '7.1.41 SATURDAY, AUGUST 3, 1895',
#  '7.1.42 SUNDAY, AUGUST 4, 1895',
#  '7.1.43 MONDAY, AUGUST 5, 1895',
#  '7.1.44 TUESDAY, AUGUST 6, 1895',
#  '7.1.5 WEDNESDAY, JUNE 26, 1895',
#  '7.1.52 THURSDAY, JULY 25, 1895',
#  '7.1.6 THURSDAY, JUNE 27, 1895',
#  '7.1.7 FRIDAY, JUNE 28, 1895',
#  '7.1.8 SATURDAY, JUNE 29, 1895',
#  '7.1.9 SUNDAY, JUNE 30, 1895',
#  '7.14',
#  '7.2 CONVERSATIONS AND DIALOGUES',
#  '7.2.1 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.10 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.11 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.12 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.13 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.14 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.15 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.16 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.17 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.18 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.19 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.2 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.20 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.21 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.22 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.23 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.24 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.25 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.26 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.27 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.28 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.29 SHARAT CHANDRA CHAKRA',
#  '7.2.29 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.30 PRIYA NATH SINHA',
#  '7.2.31 PRIYA NATH SINHA',
#  '7.2.32 MRS. WRIGHT',
#  '7.2.34 THE DETROIT FREE PRESS',
#  '7.2.4 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.5 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.53 THE APPEAL-AVALANCHE',
#  '7.2.54 THE DETROIT FREE PRESS',
#  '7.2.55 THE DETROIT TRIBUNE',
#  '7.2.6 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.7 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.8 SHARAT CHANDRA CHAKRAVARTY',
#  '7.2.9 SHARAT CHANDRA CHAKRAVARTY',
#  '7.3 TRANSLATION OF WRITINGS',
#  '7.3.1 NOTE',
#  '7.3.2 MEMOIRS OF EUROPEAN TRAVEL I',
#  '7.3.3 MEMOIRS OF EUROPEAN TRAVEL II',
#  '7.3.4 ADDENDA',
#  '7.3.5 MEMOIRS OF EUROPEAN TRAVEL II',
#  '7.4 NOTES',
#  '7.4.1 ON ART',
#  '7.4.10 SHRI RAMAKRISHNA: THE NATION’S IDEAL',
#  '7.4.11 MERCINARIES IN RELIGION',
#  '7.4.12 THE DESTINY OF MAN',
#  '7.4.13 REINCARNATION',
#  '7.4.14 COMPARATIVE THEOLOGY',
#  '7.4.15 BUDDHISM, THE RELIGION OF THE LIGHT OF ASIA',
#  '7.4.16 THE SCIENCE OF YOGA',
#  '7.4.2 ON MUSIC',
#  '7.4.3 ON MANTRA AND MA',
#  '7.4.3 ON MANTRA AND MANTRA-CHAITANYA',
#  '7.4.4 ON CONCEPTIONS OF GODHEAD',
#  '7.4.5 ON FOOD',
#  '7.4.6 ON SANNYASA AND FAMILY LIFE',
#  '7.4.7 ON QUESTIONING THE COMPETENCY OF THE GURU',
#  '7.4.8 SHRI RAMAKRISHNA:',
#  '7.4.8 SHRI RAMAKRISHNA: TE',
#  '7.4.9 ON SHRI RAMAKRISHNA AND HIS VIEWS',
#  '7.5 EPISTLES — THIRD SERIES',
#  '7.5.0 NOTE',
#  '7.5.1 BALARAM BOSE',
#  '7.5.10 PROF. JOHN HENRY WRIGHT',
#  '7.5.11 MRS. TANNATT WOODS',
#  '7.5.12 PROF. JOHN HENRY WRIGHT',
#  '7.5.13 MRS. WOODS',
#  '7.5.14 MISS HARRIET MCKINDLEY',
#  '7.5.15 REV. R. A. HUME',
#  '7.5.16 PROF. JOHN HENRY WRIGHT',
#  '7.5.16 PROF. sone HENRY WRIGHT',
#  '7.5.17 MISS ISABELLE MCKINDLEY',
#  '7.5.18 MISS ISABELLE MCKINDLEY',
#  '7.5.19 PROF. JOHN HENRY WRIGHT',
#  '7.5.2 BALARAM BOSE',
#  '7.5.20 PROF. JOHN HENRY WRIGHT',
#  '7.5.21 PROF. JOHN HENRY WRIGHT',
#  '7.5.22 PROF. JOHN HENRY WRIGHT',
#  '7.5.23 MANMATHA NATH BHATTACHA!',
#  '7.5.23 MANMATHA NATH BHATTACHARYA',
#  '7.5.24 ABHEDANANDA',
#  '7.5.25 SHIVANANDA',
#  '7.5.26 SWAMI BRAHMANANDA',
#  '7.5.27 ALASINGA',
#  '7.5.28 DR. I. JANES',
#  '7.5.29 DEAR _',
#  '7.5.29 DEAR __',
#  '7.5.30 RAKHAL',
#  '7.5.31 ALASINGA',
#  '7.5.32 ALAMBAZAR MATH MEMBERS',
#  '7.5.34 RAMAKRISHNANANDA',
#  '7.5.35 PROF JOHN HENRY WRIGHT',
#  '7.5.36 MISS NOBLE',
#  '7.5.37 DR. L. I. JANES',
#  '7.5.38 SHARAT CHANDRA CHAKRAVARTY',
#  '7.5.39 MRS. BULL',
#  '7.5.4 BALARAM BOSE',
#  '7.5.40 SHUDDHANANDA',
#  '7.5.41 MISS NOBLE',
#  '7.5.42 MISS NOBLE',
#  '7.5.43 SMT. SARALA GHOSAL',
#  '7.5.44 E. T. STURDY',
#  '7.5.45 MRS. LEGGETT',
#  '7.5.46 MRS. LEGGETT',
#  '7.5.47 MARGOT',
#  '7.5.48 MRS. LEGGETT',
#  '7.5.49 MRS. LEGETT',
#  '7.5.5 BALARAM BOSE',
#  '7.5.5 GUPTA',
#  '7.5.50 MRS. LEGETT',
#  '7.5.50 RAKHAL',
#  '7.5.51 ALASINGA',
#  '7.5.51 MR. LEGGETT',
#  '7.5.52 ALAMBAZAR MATH MEMBERS',
#  '7.5.52 AUNT ROXY',
#  '7.5.53 MISS ALBERTA STURGES',
#  '7.5.53 SISTER',
#  '7.5.55 PROF JOHN HENRY WRIGHT',
#  '7.5.56 MISS NOBLE',
#  '7.5.58 SHARAT CHANDRA CHAKRAVARTY',
#  '7.5.6 BALARAM BOSE',
#  '7.5.7 ATUL CHANDRA GHOSH',
#  '7.5.8 PROF. JOHN HENRY WRIGHT',
#  '7.5.9 PROF. JOHN HENRY WRIGHT',
#  '8.1 LEGTURES AND DISCOURSES',
#  '8.1.1 JNANA YOGA',
#  '8.1.1.1 JNANA YOGA',
#  '8.1.1.2 JNANA YOGA',
#  '8.1.1.4 JNANA YOGA',
#  '8.1.1.5 JNANA YOGA',
#  '8.1.1.6 JNANA YOGA',
#  '8.1.1.7 JNANA YOGA',
#  '8.1.1.8 JNANA YOGA',
#  '8.1.1.9 JNANA YOGA',
#  '8.1.119 SISTER NIVEDITA',
#  '8.1.2 SIX LESSONS ON RAJA-YOGA',
#  '8.1.2.1 RAJA-YOGA',
#  '8.1.2.2 RAJA YOGA',
#  '8.1.2.4 RAJA YOGA',
#  '8.1.2.5 RAJA YOGA',
#  '8.1.2.6 RAJA YOGA',
#  '8.1.3 WOMEN OF INDIA',
#  '8.1.4 MY LIFE AND MISSION',
#  '8.1.5 BUDDHA’S MESSAGE TO THE WORLD',
#  '8.1.5 WOMEN OF INDIA',
#  '8.1.6 DISCIPLESHIP',
#  '8.1.7 IS VEDANTA THE FUTURE RELIGION?',
#  '8.2 WRITINGS: PROSE',
#  '8.2.1 STRUGGLE FOR EXPANSION',
#  '8.2.2 THE BIRTH OF RELIGION',
#  '8.2.3 FOUR PATHS OF YOGA',
#  '8.2.4 CYCLIC REST AND CHANGE',
#  '8.2.5 A PREFACE TO THE IMITATION OF CHRIST',
#  '8.2.5 FOUR PATHS OF YOGA',
#  '8.3 WRITINGS: POEMS',
#  '8.3.1 AN INTERESTING CORRESPONDENCE',
#  '8.3.10 A HYMN TO SHRI RAMAKRISHNA',
#  '8.3.11 A HYMN TO SHRI RAMAKRISHNA',
#  '8.3.12 NO ONE TO BLAME',
#  '8.3.2 THOU BLESSED DREAM',
#  '8.3.3. LIGHT',
#  '8.3.4 THE LIVING GOD',
#  '8.3.5 TO AN EARLY VIOLET',
#  '8.3.6 TO MY OWN SOUL',
#  '8.3.7 THE DANCE OF SHIVA',
#  '8.3.8 SHIVA IN ECSTASY',
#  '8.3.9 TO SHRI KRISHNA',
#  '8.4.1 NOTES OF CLASS TALKS',
#  '8.4.10 INDIA',
#  '8.4.11 HINDUS AND CHRISTIAN',
#  '8.4.11 HINDUS AND CHRISTIANS',
#  '8.4.12 CHRISTIANITY IN INDIA',
#  '8.4.13 THE RELIGION OF LOVE',
#  '8.4.14 JNANA AND KARMA',
#  '8.4.15 THE CLAIMS OF VEDANTA ON THE MODERN WORLD',
#  '8.4.15 THE RELIGION OF LOVE',
#  '8.4.16 THE LAWS OF LIFE AND DEATH',
#  '8.4.17 THE REALITY AND THE SHADOW',
#  '8.4.18 WAY TO SALVATION',
#  '8.4.19 THE PEOPLE OF INDIA',
#  '8.4.2 MAN THE MAKER OF HIS DESTINY',
#  '8.4.20 I AM THAT I AM',
#  '8.4.21 UNITY',
#  '8.4.22 THE WORSHIP OF THE DIVINE MOTHER',
#  '8.4.23 THE ESSENCE OF RELIGION',
#  '8.4.25 THE ESSENCE OF RELIGION',
#  '8.4.3 GOD: PERSONAL AND IMPERSONAL',
#  '8.4.4 THE DIVINE INCARNATION OR AVATARA',
#  '8.4.5 GOD: PERSONAL AND IMPERSONAL',
#  '8.4.5 PRANAYAMA',
#  '8.4.6 WOMEN OF THE EAST',
#  '8.4.7 CONGRESS OF RELIGIOUS UNITY',
#  '8.4.8 THE LOVE OF GOD-I',
#  '8.4.9 THE LOVE OF GOD-II',
#  '8.4.NOTES OF CLASS TALKS AND',
#  '8.47.',
#  '8.5 SAYINGS AND UTTERANCES',
#  '8.6 EPISTLES - FOURTH SERIES',
#  '8.6 EPISTLES — FOURTH SERIES',
#  '8.6.0 NOTE',
#  '8.6.1 PRAMADADAS MITRA',
#  '8.6.10 HARIPADA MITRA',
#  '8.6.100 SWAMI RAMAKRISHNANANDA',
#  '8.6.102 SWAMI BRAHMANANDA',
#  '8.6.103 SWAMI BRAHMANANDA',
#  '8.6.104 SWAMI SHUDDHANANDA',
#  '8.6.105 HARIPADA MITRA',
#  '8.6.106 MISS JOSEPHINE MACLEOD',
#  '8.6.107 SWAMI BRAHMANANDA',
#  '8.6.108 SWAMI RAMAKRISHNANANDA',
#  '8.6.109 SWAMI BRAHMANANDA',
#  '8.6.11 ALASINGA PERUMAL',
#  '8.6.110 SISTER NIVEDITA',
#  '8.6.111 SWAMI BRAHMANANDA',
#  '8.6.112 SWAMI BRAHMANANDA',
#  '8.6.113 SISTER NIVEDITA',
#  '8.6.114 SWAMI BRAHMANANDA',
#  ...]

# %% [markdown]
# # Basic EDA<a class="anchor" id="chapter2"></a>

# %% [markdown]
# ## Occurrence of sentences <a class="anchor" id="section_2_1"></a>

# %%
strating_sentence = "OUR MASTER AND HIS MESSAGE"
pattern = re.compile(strating_sentence)
starting_pointer = re.search(pattern, book).end()
print("Number of sentences: ", len(book[starting_pointer:].split(". ")))
# Out:
# Number of sentences:  79340

# %% [markdown]
# ## Occurrence of words <a class="anchor" id="section_2_2"></a>

# %%
cleaned_text = clean(book.replace("’",""),extra_spaces= True, lowercase= True, punct= True) # Basic preprocessing
cleaned_text = remove_sw(cleaned_text) # Removing stopwords
cleaned_text = cleaned_text.replace("—", '')
cleaned_text = clean_text(cleaned_text)

def remove_numerals_and_one_char_words(input_text):
    # Remove numerals
    text_without_numerals = re.sub(r'\b\d+\b', '', input_text)

    # Remove one-character words
    text_without_one_char_words = ' '.join(word for word in text_without_numerals.split() if len(word) > 1)

    # Remove extra spaces
    cleaned_text = ' '.join(text_without_one_char_words.split())

    return cleaned_text

cleaned_text = remove_numerals_and_one_char_words(cleaned_text)
cleaned_text = lemmatize(cleaned_text) # lemmatization
